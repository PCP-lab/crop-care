# %%
# ==========================================================
# FAST Text Variant Generator (batched LLM + semantic filtering + resume/continue)
# ==========================================================
import os, re, json, random, math, difflib, time
from typing import List, Dict
from tqdm import tqdm

# ----------------- CONFIG -----------------
REPO_ROOT = "/home/myid/bp67339/code/crop-care/backend"
DATA_DIR  = f"{REPO_ROOT}/data"

IN_TRAIN   = f"{DATA_DIR}/train_clean_step1.jsonl"          # [{"text":"...", "label":"..."}]
OUT_AUG    = f"{DATA_DIR}/train_phase3_augmented.jsonl"     # originals + LLM variants
OUT_PAIRS  = f"{DATA_DIR}/train_phase3_pairs.jsonl"         # (orig, variant) for consistency eval
OUT_REPORT = f"{DATA_DIR}/phase3_generation_report_llm.txt"
PROGRESS_FP= f"{DATA_DIR}/phase3_progress.json"             # resume checkpoint

# Small/fast instruct model (you can switch later)
HF_MODEL = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# Speed knobs
BATCH_SIZE         = 16
VARIANTS_PER_SEED  = 2
MAX_NEW_TOKENS     = 80
TEMPERATURE        = 0.6
TOP_P              = 0.9
REPETITION_PENALTY = 1.05
SAVE_EVERY         = 500

# Scope
MAX_SEEDS          = None   # process all
SHUFFLE_SEEDS      = False  # deterministic continuation

# Optional heavy filters (off for speed)
USE_SBERT    = False
SBERT_MODEL  = "sentence-transformers/all-MiniLM-L6-v2"
SBERT_THRESH = 0.80
USE_NLI      = False
NLI_MODEL    = "roberta-large-mnli"

random.seed(42)
os.makedirs(DATA_DIR, exist_ok=True)

# ----------------- IO helpers -----------------
def read_jsonl(fp):
    rows=[]
    with open(fp,"r",encoding="utf-8") as f:
        for line in f:
            line=line.strip()
            if not line: continue
            rows.append(json.loads(line))
    return rows

def write_jsonl(fp, rows):
    os.makedirs(os.path.dirname(fp), exist_ok=True)
    with open(fp,"w",encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

# ----------------- Load seeds -----------------
rows = read_jsonl(IN_TRAIN)
print("Loaded:", len(rows))
if SHUFFLE_SEEDS:
    random.shuffle(rows)
if MAX_SEEDS:
    rows = rows[:MAX_SEEDS]
    print("Using subset:", len(rows))

# ----------------- Filters (lightweight) -----------------
def toks(s): return re.findall(r"[a-zA-Z']+", s.lower())
def keyword_set(s):
    stop=set("""a an the and or but if so then than with without of on in to for from by at is are was were be been being it its it's im i'm i you your u our we they them this that those these there's""".split())
    return set([w for w in toks(s) if w not in stop and len(w)>=3])

def similarity(a,b):  # fast string sim just for guardrails
    return difflib.SequenceMatcher(None, a.lower(), b.lower()).ratio()

def keep_variant(orig, var):
    var=var.strip()
    if not var or len(var.split())<5 or len(var)>400: return False
    sim=similarity(orig,var)
    if sim>=0.98 or sim<0.50: return False
    base=keyword_set(orig); ks=keyword_set(var)
    if len(base & ks) < max(1, min(3, math.ceil(0.2*len(base)))): return False
    if var.lower().startswith("disease:"): return False
    return True

# ----------------- Load LLM -----------------
import torch, importlib.util
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

load_kwargs = {"device_map": "auto"}
use_4bit = torch.cuda.is_available() and importlib.util.find_spec("bitsandbytes") is not None
if use_4bit:
    load_kwargs["load_in_4bit"] = True
    print("Using 4-bit quantization via bitsandbytes.")
else:
    print("bitsandbytes not found (or no CUDA). Using regular precision.")

tokenizer = AutoTokenizer.from_pretrained(HF_MODEL, use_fast=True)
if tokenizer.pad_token_id is None and tokenizer.eos_token_id is not None:
    tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    HF_MODEL,
    torch_dtype=(torch.float16 if torch.cuda.is_available() else torch.float32),
    **load_kwargs
)

gen = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=MAX_NEW_TOKENS,
    temperature=TEMPERATURE,
    top_p=TOP_P,
    do_sample=True,
    repetition_penalty=REPETITION_PENALTY,
    pad_token_id=tokenizer.pad_token_id,
    eos_token_id=tokenizer.eos_token_id,
    return_full_text=False,
)
print("Accelerate device map:", getattr(model, "hf_device_map", None))

# ----------------- Prompting -----------------
SYSTEM_MSG = (
    "You rewrite plant disease descriptions into short, farmer-style sentences "
    "while strictly preserving the original meaning and symptoms. "
    "Do not add or remove symptoms. Do not name a disease. 1–2 sentences max."
)

def clamp(txt, max_chars=600):
    return txt if len(txt) <= max_chars else (txt[:max_chars] + "…")

def build_prompt(text, n):
    return (
        f"{SYSTEM_MSG}\n\n"
        f"ORIGINAL:\n{clamp(text)}\n\n"
        f"Write {n} farmer-style variants that preserve meaning. "
        f"Output EXACTLY a JSON list of strings (no extra text)."
    )

def parse_json_list(s: str):
    m = re.search(r"\[[\s\S]*\]", s)
    if not m: return []
    try:
        arr = json.loads(m.group(0))
        if isinstance(arr, list):
            return [x.strip() for x in arr if isinstance(x,str) and x.strip()]
    except Exception:
        return []
    return []

def get_generated_text(item):
    if isinstance(item, list):
        item = item[0]
    return item.get("generated_text", "")

# ----------------- Continue from existing -----------------
seen_orig, seen_dupes = set(), set()
out_rows, pairs_rows = [], []

if os.path.exists(OUT_AUG):
    out_rows = read_jsonl(OUT_AUG)
    for r in out_rows:
        txt  = (r.get("text") or "").strip().lower()
        lbl  = r.get("label")
        src  = r.get("source")
        if not txt or not lbl: 
            continue
        if src == "orig":
            seen_orig.add((lbl, txt))
        elif src == "aug":
            seen_dupes.add((lbl, txt))

if os.path.exists(OUT_PAIRS):
    pairs_rows = read_jsonl(OUT_PAIRS)

print(f"Already have {len(seen_orig)} originals and {len(seen_dupes)} aug variants from previous runs.")

# Filter to only remaining
def norm(s): return (s or "").strip().lower()
remaining_rows = []
for r in rows:
    base  = norm(r.get("text"))
    label = r.get("label")
    if base and label and (label, base) not in seen_orig:
        remaining_rows.append({"text": base, "label": label})

rows = remaining_rows
print("Remaining to process:", len(rows))

# Reset progress file
if os.path.exists(PROGRESS_FP):
    os.remove(PROGRESS_FP)

# ----------------- Batch loop -----------------
def process_batch(batch_rows):
    prompts = [build_prompt((r.get("text") or "").strip(), VARIANTS_PER_SEED) for r in batch_rows]
    return gen(prompts, batch_size=BATCH_SIZE)

print("Generating variants in batches…")
B = BATCH_SIZE
total = len(rows)
num_batches = (total + B - 1) // B
t0 = time.time()

for b, i in enumerate(tqdm(range(0, total, B), total=num_batches)):
    batch_rows = rows[i : min(i+B, total)]

    # add originals
    for r in batch_rows:
        base = (r.get("text") or "").strip()
        label= r.get("label")
        if not base or not label: 
            continue
        out_rows.append({"text": base, "label": label, "source":"orig", "tags":[]})

    # generate batch
    try:
        outs = process_batch(batch_rows)
    except Exception as e:
        print(f"\nBatch {i}-{i+len(batch_rows)} failed: {e}")
        continue

    # parse/filter
    for r, out in zip(batch_rows, outs):
        base  = (r.get("text") or "").strip()
        label = r.get("label")
        if not base or not label: 
            continue
        text_out = get_generated_text(out)
        cand = parse_json_list(text_out)
        if not cand:
            cand = [ln.strip(" -") for ln in text_out.split("\n") if len(ln.strip())>10][:VARIANTS_PER_SEED]

        kept_here = 0
        for v in cand:
            if kept_here >= VARIANTS_PER_SEED: break
            if not keep_variant(base, v): continue
            key=(label, v.lower().strip())
            if key in seen_dupes: continue
            seen_dupes.add(key)
            out_rows.append({"text": v, "label": label, "source":"aug", "tags":["llm"]})
            pairs_rows.append({"orig": base, "variant": v, "label": label, "tags":["llm"]})
            kept_here += 1

    # periodic save
    if (b + 1) % max(1, SAVE_EVERY // B) == 0:
        write_jsonl(OUT_AUG, out_rows)
        write_jsonl(OUT_PAIRS, pairs_rows)

# final save
write_jsonl(OUT_AUG, out_rows)
write_jsonl(OUT_PAIRS, pairs_rows)
with open(OUT_REPORT,"w") as f:
    f.write(f"Seeds used: {len(rows)}\n")
    f.write(f"Total (orig+aug): {len(out_rows)}\n")
    f.write(f"Pairs: {len(pairs_rows)}\n")
    f.write(f"Model: {HF_MODEL} | Batch: {BATCH_SIZE} | Variants/seed: {VARIANTS_PER_SEED} | MaxNewTokens: {MAX_NEW_TOKENS}\n")
    f.write(f"Took {(time.time()-t0)/60:.1f} min\n")

print("✅ Saved")
print("  Augmented:", OUT_AUG)
print("  Pairs:    ", OUT_PAIRS)
print("  Report:   ", OUT_REPORT)
print(f"Final counts — originals: {sum(1 for r in out_rows if r['source']=='orig')}, "
      f"variants: {sum(1 for r in out_rows if r['source']=='aug')}, pairs: {len(pairs_rows)}")
# Out:
# Loaded: 44494
# bitsandbytes not found (or no CUDA). Using regular precision.
# Device set to use cuda:0
# Accelerate device map: {'model.embed_tokens': 0, 'model.layers.0': 0, 'model.layers.1': 0, 'model.layers.2': 0, 'model.layers.3': 0, 'model.layers.4': 0, 'model.layers.5': 0, 'model.layers.6': 0, 'model.layers.7': 0, 'model.layers.8': 0, 'model.layers.9': 0, 'model.layers.10': 0, 'model.layers.11': 0, 'model.layers.12': 0, 'model.layers.13': 0, 'model.layers.14': 0, 'model.layers.15': 0, 'model.layers.16': 0, 'model.layers.17': 0, 'model.layers.18': 0, 'model.layers.19': 0, 'model.layers.20': 0, 'model.layers.21': 1, 'model.norm': 1, 'model.rotary_emb': 1, 'lm_head': 1}
# Already have 5000 originals and 2870 aug variants from previous runs.
# Remaining to process: 39493
# Generating variants in batches…
#   0%|          | 0/2469 [00:00<?, ?it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 1/2469 [00:02<1:29:47,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 2/2469 [00:04<1:30:22,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 3/2469 [00:06<1:30:17,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 4/2469 [00:08<1:29:43,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 5/2469 [00:10<1:29:56,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 6/2469 [00:13<1:29:38,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 7/2469 [00:15<1:29:26,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 8/2469 [00:17<1:32:18,  2.25s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 9/2469 [00:19<1:31:37,  2.23s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 10/2469 [00:22<1:31:04,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 11/2469 [00:24<1:30:29,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   0%|          | 12/2469 [00:26<1:30:03,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 13/2469 [00:28<1:29:49,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 14/2469 [00:30<1:29:23,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 15/2469 [00:32<1:29:02,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 16/2469 [00:35<1:29:03,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 17/2469 [00:37<1:28:52,  2.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 18/2469 [00:39<1:28:45,  2.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 19/2469 [00:41<1:28:57,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 20/2469 [00:43<1:29:00,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 21/2469 [00:46<1:28:48,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 22/2469 [00:48<1:28:46,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 23/2469 [00:50<1:28:53,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 24/2469 [00:52<1:28:48,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 25/2469 [00:54<1:29:05,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 26/2469 [00:56<1:29:02,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 27/2469 [00:59<1:28:36,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 28/2469 [01:01<1:28:27,  2.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 29/2469 [01:03<1:28:23,  2.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|          | 30/2469 [01:05<1:28:37,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 31/2469 [01:09<1:47:36,  2.65s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 32/2469 [01:11<1:41:50,  2.51s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 33/2469 [01:13<1:38:07,  2.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 34/2469 [01:15<1:35:03,  2.34s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 35/2469 [01:18<1:33:15,  2.30s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 36/2469 [01:20<1:31:43,  2.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   1%|▏         | 37/2469 [01:22<1:31:01,  2.25s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 38/2469 [01:24<1:30:06,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 39/2469 [01:26<1:29:37,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 40/2469 [01:29<1:29:37,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 41/2469 [01:31<1:29:20,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 42/2469 [01:33<1:29:10,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 43/2469 [01:35<1:29:37,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 44/2469 [01:37<1:29:05,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 45/2469 [01:40<1:28:48,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 46/2469 [01:42<1:28:40,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 47/2469 [01:44<1:28:32,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 48/2469 [01:46<1:28:23,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 49/2469 [01:48<1:28:17,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 50/2469 [01:51<1:28:18,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 51/2469 [01:53<1:28:26,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 52/2469 [01:55<1:28:12,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 53/2469 [01:57<1:27:56,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 54/2469 [01:59<1:28:00,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 55/2469 [02:01<1:28:12,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 56/2469 [02:04<1:28:00,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 57/2469 [02:06<1:27:50,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 58/2469 [02:08<1:28:01,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 59/2469 [02:10<1:28:04,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 60/2469 [02:12<1:27:54,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   2%|▏         | 61/2469 [02:15<1:27:55,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 62/2469 [02:17<1:28:23,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 63/2469 [02:19<1:28:20,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 64/2469 [02:21<1:27:48,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 65/2469 [02:23<1:27:36,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 66/2469 [02:26<1:27:46,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 67/2469 [02:28<1:27:36,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 68/2469 [02:30<1:27:27,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 69/2469 [02:32<1:27:13,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 70/2469 [02:34<1:27:11,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 71/2469 [02:36<1:27:04,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 72/2469 [02:39<1:27:30,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 73/2469 [02:41<1:27:39,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 74/2469 [02:43<1:27:39,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 75/2469 [02:45<1:27:39,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 76/2469 [02:48<1:27:47,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 77/2469 [02:50<1:27:36,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 78/2469 [02:52<1:30:06,  2.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 79/2469 [02:54<1:29:21,  2.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 80/2469 [02:56<1:28:12,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 81/2469 [02:59<1:27:39,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 82/2469 [03:01<1:27:12,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 83/2469 [03:03<1:26:53,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 84/2469 [03:05<1:26:43,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 85/2469 [03:07<1:26:25,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 86/2469 [03:09<1:26:33,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 87/2469 [03:12<1:26:16,  2.17s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 88/2469 [03:14<1:26:25,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 89/2469 [03:16<1:26:31,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 90/2469 [03:18<1:26:28,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 91/2469 [03:20<1:26:24,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▎         | 92/2469 [03:23<1:26:52,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 93/2469 [03:25<1:27:57,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 94/2469 [03:27<1:27:44,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 95/2469 [03:29<1:27:25,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 96/2469 [03:31<1:27:11,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 97/2469 [03:34<1:27:01,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 98/2469 [03:36<1:26:51,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 99/2469 [03:38<1:27:03,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 100/2469 [03:40<1:26:42,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 101/2469 [03:42<1:26:32,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 102/2469 [03:45<1:26:18,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 103/2469 [03:47<1:26:07,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 104/2469 [03:49<1:26:02,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 105/2469 [03:51<1:26:04,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 106/2469 [03:53<1:26:09,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 107/2469 [03:56<1:26:16,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 108/2469 [03:58<1:26:08,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 109/2469 [04:00<1:26:14,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 110/2469 [04:02<1:26:05,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   4%|▍         | 111/2469 [04:04<1:26:19,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 112/2469 [04:07<1:26:00,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 113/2469 [04:09<1:25:59,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 114/2469 [04:11<1:25:43,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 115/2469 [04:13<1:25:48,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 116/2469 [04:15<1:25:34,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 117/2469 [04:17<1:25:19,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 118/2469 [04:20<1:25:33,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 119/2469 [04:22<1:25:21,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 120/2469 [04:24<1:25:37,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 121/2469 [04:26<1:25:48,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 122/2469 [04:28<1:25:42,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▍         | 123/2469 [04:31<1:25:31,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 124/2469 [04:33<1:26:23,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 125/2469 [04:35<1:26:06,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 126/2469 [04:37<1:25:53,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 127/2469 [04:39<1:25:56,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 128/2469 [04:42<1:25:54,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 129/2469 [04:44<1:26:09,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 130/2469 [04:46<1:26:08,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 131/2469 [04:48<1:25:51,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 132/2469 [04:50<1:25:50,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 133/2469 [04:53<1:25:43,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 134/2469 [04:55<1:26:01,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   5%|▌         | 135/2469 [04:57<1:26:03,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 136/2469 [04:59<1:25:49,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 137/2469 [05:01<1:25:34,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 138/2469 [05:04<1:25:41,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 139/2469 [05:06<1:25:20,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 140/2469 [05:08<1:25:19,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 141/2469 [05:10<1:25:29,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 142/2469 [05:12<1:25:02,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 143/2469 [05:15<1:25:15,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 144/2469 [05:17<1:25:06,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 145/2469 [05:19<1:24:51,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 146/2469 [05:21<1:24:57,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 147/2469 [05:24<1:26:56,  2.25s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 148/2469 [05:26<1:26:03,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 149/2469 [05:28<1:25:18,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 150/2469 [05:30<1:25:11,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 151/2469 [05:32<1:24:47,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 152/2469 [05:34<1:24:23,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 153/2469 [05:37<1:24:20,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▌         | 154/2469 [05:39<1:24:15,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 155/2469 [05:43<1:44:45,  2.72s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 156/2469 [05:45<1:38:54,  2.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 157/2469 [05:47<1:34:14,  2.45s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 158/2469 [05:49<1:31:10,  2.37s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 159/2469 [05:52<1:28:54,  2.31s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 160/2469 [05:54<1:27:24,  2.27s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 161/2469 [05:56<1:26:12,  2.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 162/2469 [05:58<1:25:23,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 163/2469 [06:00<1:25:12,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 164/2469 [06:02<1:24:39,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 165/2469 [06:05<1:24:30,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 166/2469 [06:07<1:24:08,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 167/2469 [06:09<1:24:26,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 168/2469 [06:11<1:24:34,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 169/2469 [06:13<1:24:25,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 170/2469 [06:16<1:24:09,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 171/2469 [06:18<1:23:43,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 172/2469 [06:20<1:23:40,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 173/2469 [06:22<1:23:33,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 174/2469 [06:24<1:23:45,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 175/2469 [06:27<1:24:14,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 176/2469 [06:29<1:24:48,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 177/2469 [06:31<1:24:35,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 178/2469 [06:33<1:24:32,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 179/2469 [06:35<1:24:12,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 180/2469 [06:38<1:24:24,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 181/2469 [06:40<1:23:52,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 182/2469 [06:42<1:23:45,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 183/2469 [06:44<1:23:20,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 184/2469 [06:46<1:23:17,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   7%|▋         | 185/2469 [06:49<1:22:52,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 186/2469 [06:51<1:24:09,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 187/2469 [06:53<1:23:40,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 188/2469 [06:55<1:24:05,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 189/2469 [06:57<1:23:46,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 190/2469 [07:00<1:23:28,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 191/2469 [07:02<1:23:08,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 192/2469 [07:04<1:22:56,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 193/2469 [07:06<1:22:54,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 194/2469 [07:08<1:22:51,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 195/2469 [07:11<1:22:50,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 196/2469 [07:13<1:22:50,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 197/2469 [07:15<1:23:04,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 198/2469 [07:17<1:23:14,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 199/2469 [07:19<1:22:53,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 200/2469 [07:21<1:22:34,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 201/2469 [07:24<1:22:32,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 202/2469 [07:26<1:22:31,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 203/2469 [07:28<1:22:30,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 204/2469 [07:30<1:22:27,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 205/2469 [07:32<1:22:35,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 206/2469 [07:35<1:22:25,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 207/2469 [07:37<1:22:11,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 208/2469 [07:39<1:22:11,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   8%|▊         | 209/2469 [07:41<1:22:14,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...
#  97%|█████████▋| 2400/2469 [1:34:24<02:31,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2401/2469 [1:34:27<02:28,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2402/2469 [1:34:29<02:26,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2403/2469 [1:34:31<02:23,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2404/2469 [1:34:33<02:21,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2405/2469 [1:34:35<02:19,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2406/2469 [1:34:37<02:17,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 2407/2469 [1:34:40<02:15,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2408/2469 [1:34:42<02:13,  2.18s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2409/2469 [1:34:44<02:11,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2410/2469 [1:34:46<02:09,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2411/2469 [1:34:48<02:07,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2412/2469 [1:34:51<02:05,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2413/2469 [1:34:53<02:03,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2414/2469 [1:34:55<02:00,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2415/2469 [1:34:57<01:58,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2416/2469 [1:34:59<01:56,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2417/2469 [1:35:02<01:54,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2418/2469 [1:35:05<02:14,  2.63s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2419/2469 [1:35:07<02:05,  2.50s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2420/2469 [1:35:10<01:58,  2.41s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2421/2469 [1:35:12<01:52,  2.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2422/2469 [1:35:14<01:48,  2.30s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2423/2469 [1:35:16<01:44,  2.27s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2424/2469 [1:35:18<01:40,  2.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2425/2469 [1:35:21<01:37,  2.22s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2426/2469 [1:35:23<01:34,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2427/2469 [1:35:25<01:32,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2428/2469 [1:35:27<01:30,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2429/2469 [1:35:29<01:27,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2430/2469 [1:35:32<01:25,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  98%|█████████▊| 2431/2469 [1:35:34<01:23,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2432/2469 [1:35:36<01:21,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2433/2469 [1:35:38<01:18,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2434/2469 [1:35:40<01:16,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2435/2469 [1:35:43<01:14,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2436/2469 [1:35:45<01:12,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2437/2469 [1:35:47<01:10,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▊| 2438/2469 [1:35:49<01:07,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2439/2469 [1:35:51<01:05,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2440/2469 [1:35:53<01:03,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2441/2469 [1:35:56<01:01,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2442/2469 [1:35:58<00:59,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2443/2469 [1:36:00<00:56,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2444/2469 [1:36:02<00:54,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2445/2469 [1:36:04<00:52,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2446/2469 [1:36:07<00:50,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2447/2469 [1:36:09<00:48,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2448/2469 [1:36:11<00:46,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2449/2469 [1:36:15<00:54,  2.72s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2450/2469 [1:36:17<00:48,  2.57s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2451/2469 [1:36:19<00:44,  2.46s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2452/2469 [1:36:22<00:40,  2.38s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2453/2469 [1:36:24<00:37,  2.33s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2454/2469 [1:36:26<00:34,  2.28s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2455/2469 [1:36:28<00:31,  2.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  99%|█████████▉| 2456/2469 [1:36:30<00:29,  2.24s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2457/2469 [1:36:33<00:26,  2.23s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2458/2469 [1:36:35<00:24,  2.21s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2459/2469 [1:36:37<00:22,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2460/2469 [1:36:39<00:19,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2461/2469 [1:36:41<00:17,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2462/2469 [1:36:44<00:15,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2463/2469 [1:36:46<00:13,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2464/2469 [1:36:48<00:11,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2465/2469 [1:36:50<00:08,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2466/2469 [1:36:52<00:06,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2467/2469 [1:36:54<00:04,  2.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|█████████▉| 2468/2469 [1:36:57<00:02,  2.20s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 2469/2469 [1:36:59<00:00,  2.36s/it]
# ✅ Saved
#   Augmented: /home/myid/bp67339/code/crop-care/backend/data/train_phase3_augmented.jsonl
#   Pairs:     /home/myid/bp67339/code/crop-care/backend/data/train_phase3_pairs.jsonl
#   Report:    /home/myid/bp67339/code/crop-care/backend/data/phase3_generation_report_llm.txt
# Final counts — originals: 44493, variants: 25928, pairs: 25928
